# %% [markdown]
# # importing needful libraries

# %%
import pandas as pd

# %%
customer_feedback_df = pd.read_csv('customer_feedback.csv')
product_catalog_df = pd.read_csv('product_catalog.csv')
sales_data_df = pd.read_csv('sales_data.csv')
search_trends_df = pd.read_csv('search_trends.csv')

# %% [markdown]
# # EDA

# %%
customer_feedback_df.head()
# Out:
#   productId                                        commentText  rating  \
# 0     P1001  Honestly, I found this tank top to be uncomfor...     2.0
# 1     P1001               sizing and the material felt cheap..     4.0
# 2     P1001                          delivery was late.. 🤷‍♂️🔥     5.0
# 3     P1001  From my experience, the tank top was perfect. ...     4.0
# 4     P1001  The tank top is stylish. Goes well with everyt...     4.0
#
#            reviewerName            location        date
# 0   Angelica Littel Sr.     North Celestine  2024-02-18
# 1            Ronald Fay       Halvorsonboro  2023-12-01
# 2     Dr. Lloyd Smitham           New Ciara  2024-10-28
# 3  Christopher Hartmann          North Ally  2024-04-09
# 4       Jerry Bergstrom  Port Nikitaborough  2024-09-13

# %%
product_catalog_df.head()
# Out:
#   productId                         title  \
# 0     P1001          Solid Denim Tank Top
# 1     P1002  Sleeveless Plaid Trench Coat
# 2     P1003          Wool Printed Sandals
# 3     P1004           Fitted Women Romper
# 4     P1005         Loose Floral Sneakers
#
#                                          description     category  \
# 0  With influences of tank top combining solid pe...     tank top
# 1  For fans of trench coat combining sleeveless m...  trench coat
# 2  Meticulously crafted sandals combining wool st...      sandals
# 3  Inspired by romper combining fitted performanc...       romper
# 4  Made to celebrate sneakers combining loose ref...     sneakers
#
#            modifiers                     keywords releaseDate
# 0       solid, denim       loose, white, tank top  2024-08-05
# 1  sleeveless, plaid   white, winter, trench coat  2023-09-03
# 2      wool, printed         wool, olive, sandals  2023-11-22
# 3      fitted, women  sleeveless, striped, romper  2023-02-10
# 4      loose, floral     pumps, striped, sneakers  2024-04-28

# %%
sales_data_df.head()
# Out:
#   productId  quantitySold   timestamp
# 0     P1001            15  2023-10-15
# 1     P1001            25  2024-03-03
# 2     P1001            26  2023-07-26
# 3     P1001            22  2023-09-08
# 4     P1001            16  2023-10-08

# %%
search_trends_df.head()
# Out:
#                        query  frequency   timestamp
# 0               men tank top         96  2023-08-12
# 1                   tank top         70  2024-05-22
# 2               men tank top        104  2022-09-15
# 3  women olive navy tank top         52  2023-10-13
# 4              bright yellow         56  2024-12-02
